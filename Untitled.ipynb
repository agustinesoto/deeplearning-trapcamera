# %%
import pandas as pd

# %%
data = pd.read_csv("optimization_results.csv")

# %%
data.sort_values(by=['test_f1']).tail(10)
# Out:
#     Unnamed: 0                  model_name  test_accuracy  test_precision  \
# 52          52   dense256_dense128_dense64       0.860465        0.903226
# 7            7   dense64_dense128_dense256       0.860465        0.878788
# 34          34   dense192_dense64_dense192       0.860465        0.857143
# 47          47  dense192_dense256_dense256       0.860465        0.837838
# 10          10   dense64_dense192_dense192       0.860465        0.837838
# 46          46  dense192_dense256_dense192       0.860465        0.837838
# 35          35   dense192_dense64_dense256       0.860465        0.837838
# 12          12    dense64_dense256_dense64       0.860465        0.837838
# 29          29  dense128_dense256_dense128       0.883721        0.906250
# 6            6   dense64_dense128_dense192       0.883721        0.861111
#
#     test_recall   test_f1
# 52     0.903226  0.903226
# 7      0.935484  0.906250
# 34     0.967742  0.909091
# 47     1.000000  0.911765
# ...

# %%
data2 = pd.read_csv("optimization_results_13_03_2023_10_42_58.csv")
data2
# Out:
#                      model_name  epochs  test_accuracy  test_precision  \
# 0       dense64_dense64_dense64      30       0.883721        0.933333
# 1       dense64_dense64_dense64      50       0.883721        0.906250
# 2       dense64_dense64_dense64     100       0.883721        0.861111
# 3      dense64_dense64_dense128      30       0.883721        0.861111
# 4      dense64_dense64_dense128      50       0.813953        0.794872
# ..                          ...     ...            ...             ...
# 187  dense256_dense256_dense192      50       0.883721        0.861111
# 188  dense256_dense256_dense192     100       0.860465        0.837838
# 189  dense256_dense256_dense256      30       0.883721        0.933333
# 190  dense256_dense256_dense256      50       0.883721        0.933333
# 191  dense256_dense256_dense256     100       0.860465        0.878788
#
#      test_recall   test_f1
# 0       0.903226  0.918033
# 1       0.935484  0.920635
# 2       1.000000  0.925373
# ...

# %%
ordenado = data2.sort_values(by=['test_f1'],ascending=False)
ordenado.head(60)
# Out:
#                      model_name  epochs  test_accuracy  test_precision  \
# 181   dense256_dense256_dense64      50       0.953488        0.939394
# 158   dense256_dense128_dense64     100       0.953488        0.939394
# 179  dense256_dense192_dense256     100       0.953488        0.939394
# 56    dense128_dense64_dense192     100       0.953488        0.939394
# 53    dense128_dense64_dense128     100       0.953488        0.939394
# 68   dense128_dense128_dense192     100       0.953488        0.939394
# 47    dense64_dense256_dense256     100       0.953488        0.939394
# 128  dense192_dense192_dense192     100       0.953488        0.939394
# 74    dense128_dense192_dense64     100       0.953488        0.939394
# 172  dense256_dense192_dense128      50       0.953488        0.939394
# 35    dense64_dense192_dense256     100       0.953488        0.939394
# 29    dense64_dense192_dense128     100       0.953488        0.939394
# ...

# %%
data.sort_values(by=['test_f1']).tail(10)
# Out:
#     Unnamed: 0                  model_name  test_accuracy  test_precision  \
# 52          52   dense256_dense128_dense64       0.860465        0.903226
# 7            7   dense64_dense128_dense256       0.860465        0.878788
# 34          34   dense192_dense64_dense192       0.860465        0.857143
# 47          47  dense192_dense256_dense256       0.860465        0.837838
# 10          10   dense64_dense192_dense192       0.860465        0.837838
# 46          46  dense192_dense256_dense192       0.860465        0.837838
# 35          35   dense192_dense64_dense256       0.860465        0.837838
# 12          12    dense64_dense256_dense64       0.860465        0.837838
# 29          29  dense128_dense256_dense128       0.883721        0.906250
# 6            6   dense64_dense128_dense192       0.883721        0.861111
#
#     test_recall   test_f1
# 52     0.903226  0.903226
# 7      0.935484  0.906250
# 34     0.967742  0.909091
# 47     1.000000  0.911765
# ...

# %% [markdown]
# Duración 24horas app segunda iteración del código
#
#
# Principales diferencias hasta ahora, en data simplemente se entrenaron 20 épocas para todas las arquitecturas.
#
# Ambos experimentos tienen mismo dataset de entrenamiento, tuning y test

# %% [markdown]
# ---- pasos por ahora agregar también diversos modelos para ver el mejor.
# ResNet, AlexNet, VGG, Inception, DenseNet, etc
#
# Todavía no pruebo la mejor arquitectura de aquí con el código preexistente para entrenar y evaluar una sola arquitectura.
